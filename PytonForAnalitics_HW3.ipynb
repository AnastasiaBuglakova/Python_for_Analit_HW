# %% [markdown]
# ### Условие 1: Задача 1
# - Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк

# %%
import pandas as pd
df = pd.read_csv('/Users/anastasiabuglakova/Documents/GEEK/Основы Python для аналитиков/kc-house-data.csv', encoding ='1251')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
# - Если реновации дома не было, то в новом признаке поставьте 0

# %%
df.shape
# Out:
# (21613, 21)

# %%
def delta (x):
    if (x<0): return 0
    else: return x

df['delta_renovated'] = df["yr_renovated"] - df["yr_built"]
df['delta_renovated'] = df['delta_renovated'].apply(delta)
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 12233  9465910030  20140515T000000  525000.0         3       2.50
# 9869   4123800320  20150206T000000  176000.0         3       3.25
# 274    4235400186  20141124T000000  331000.0         3       1.75
# 21549  1220000371  20141231T000000  327500.0         3       2.50
# 12056  1282300105  20140604T000000  317000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 12233         2700      7434     2.0           0     0  ...        2700
# 9869          1340      5434     2.0           0     0  ...        1340
# 274           1080      1306     1.0           0     0  ...         580
# 21549         1820      1866     2.0           0     0  ...        1570
# 12056         1010      5400     1.0           0     0  ...        1010
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ### 1.3 Создайте признаки года продажи, месяца продажи

# %%
df['year_of_sale'] = df["date"].str[:4]
df.sample(5)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 18877  4399210110  20140619T000000   232603.0         3       1.75
# 8895    269000615  20140516T000000   875000.0         3       2.00
# 5669   1338600185  20140624T000000  1157400.0         3       2.50
# 18116  4326000220  20141020T000000   321000.0         3       1.00
# 11928  6403500570  20140612T000000   498500.0         5       2.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 18877         1750     11461     2.0           0     0  ...              0
# 8895          2220      6641     1.0           0     2  ...           1000
# 5669          2740      5925     2.0           0     2  ...              0
# 18116         1290      9526     1.5           0     0  ...              0
# 11928         2990      7420     2.0           0     0  ...              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df['month_of_sale'] = df["date"].str[4:6]
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 3683   2891100820  20140825T000000  213500.0         3       1.00
# 1006   7852090810  20141119T000000  515000.0         3       2.50
# 2680   2768000270  20140625T000000  562100.0         2       0.75
# 13575  2762600035  20140909T000000  279000.0         3       1.00
# 17686   226039317  20150107T000000  750000.0         4       2.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 3683          1220      6000     1.0           0     0  ...      1968
# 1006          2430      4203     2.0           0     0  ...      2001
# 2680          1440      3700     1.0           0     0  ...      1914
# 13575         1530     15975     1.0           0     0  ...      1952
# 17686         3210      8520     1.0           0     2  ...      1976
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# ### 1.4 Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns = ['date', 'zipcode', 'lat', 'long'], inplace = True)
df.sample(5)
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 8241   3262301355  1320000.0         3       2.75         2680     20104
# 4065   2475200590   244000.0         3       1.75         1460      4692
# 10146  2193340260   596500.0         4       2.25         1770      8505
# 7579   6641040100  1146800.0         4       3.50         4210     10308
# 3491   4410600100   325088.0         4       1.00         1400      6739
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 8241      1.0           0     0          5      9        1820            860
# 4065      1.0           0     0          3      7        1460              0
# 10146     2.0           0     0          3      8        1770              0
# 7579      2.0           0     0          3     10        4210              0
# 3491      1.0           0     0          3      7        1000            400
#
# ...

# %%
df.describe(include = 'object')
# Out:
#        year_of_sale month_of_sale
# count         21613         21613
# unique            2            12
# top            2014            05
# freq          14633          2414

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Условие 2: 2 задача

# %% [markdown]
# #### Создайте датафрейм с клиентами:

# %%
clients = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]
})
clients.shape
# Out:
# (32, 2)

# %% [markdown]
# ### 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df_ID=df.set_index("id")
clients_ID=clients.set_index("house_id")

# %%
clients_ID.join(df_ID).head()
# Out:
#             client_id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 339600110        4809  395000.0         3       2.50         1610      3755
# 809001400        3113  925000.0         3       1.00         1630      3200
# 825069097        1764  770000.0         3       2.50         2650     40705
# 1099600250       2242  260000.0         3       1.75         1710      6400
# 1189000207       2308  387000.0         2       2.50         1170      1394
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# 339600110      2.0           0     0          3      7        1610
# 809001400      1.5           0     0          4      8        1630
# 825069097      2.0           0     0          3      9        2650
# 1099600250     1.0           0     0          4      7        1240
# 1189000207     2.0           0     0          3      8        1170
#
#             sqft_basement  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# ### 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
#
# house_id - это индексы датафрейма с домами

# %%
clients_ID.join(df_ID).reset_index().head()
# Out:
#         index  client_id     price  bedrooms  bathrooms  sqft_living  \
# 0   339600110       4809  395000.0         3       2.50         1610
# 1   809001400       3113  925000.0         3       1.00         1630
# 2   825069097       1764  770000.0         3       2.50         2650
# 3  1099600250       2242  260000.0         3       1.75         1710
# 4  1189000207       2308  387000.0         2       2.50         1170
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      3755     2.0           0     0  ...      7        1610              0
# 1      3200     1.5           0     0  ...      8        1630              0
# 2     40705     2.0           0     0  ...      9        2650              0
# 3      6400     1.0           0     0  ...      7        1240            470
# 4      1394     2.0           0     0  ...      8        1170              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# ...

# %%
clients_merged = clients.merge(df, left_on = "house_id",right_on = "id", how = 'left')
clients_merged
# Out:
#     client_id    house_id          id      price  bedrooms  bathrooms  \
# 0        1459  8965450190  8965450190   295000.0         3       2.50
# 1        4684  6823100225  6823100225   700000.0         4       1.75
# 2        3498  5104540330  5104540330   679000.0         4       2.50
# 3        3942  2131701075  2131701075   420000.0         3       1.75
# 4        4535  1522700060  1522700060   518000.0         4       2.75
# 5        2308  1189000207  1189000207   387000.0         2       2.50
# 6        2866  6821600300  6821600300   886000.0         3       2.25
# 7        2765  7137950720  7137950720   339100.0         4       2.50
# 8        1472  9510920050  9510920050   725000.0         3       2.50
# 9        4236  6131600255  6131600255   202500.0         3       2.00
# 10       2295  5428000070  5428000070   770000.0         5       3.50
# 11        939  1788800910  1788800910   190000.0         3       1.00
# ...

# %% [markdown]
# ## Условие 3: 3 задача
# Составьте несколько сводных таблиц

# %% [markdown]
# ### 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
#
# Отсортируйте от меньшей стоимости к большей

# %%
df.pivot_table(index = 'bedrooms',
              values = 'price',
              aggfunc = 'mean',
              fill_value = '-').sort_values('price')
# Out:
#                  price
# bedrooms
# 1         3.176429e+05
# 2         4.013727e+05
# 0         4.095038e+05
# 3         4.662321e+05
# 11        5.200000e+05
# 4         6.354195e+05
# 33        6.400000e+05
# 5         7.865998e+05
# 10        8.193333e+05
# 6         8.255206e+05
# 9         8.939998e+05
# 7         9.511847e+05
# 8         1.105077e+06

# %%
df.groupby('bedrooms').agg({'price': 'mean'}).sort_values('price')

# %% [markdown]
# ### 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby("grade").agg({'price': ['min', 'mean','max']})
# Out:
#            price
#              min          mean        max
# grade
# 1       142000.0  1.420000e+05   142000.0
# 3        75000.0  2.056667e+05   280000.0
# 4        80000.0  2.143810e+05   435000.0
# 5        78000.0  2.485240e+05   795000.0
# 6        82000.0  3.019196e+05  1200000.0
# 7        90000.0  4.025903e+05  2050000.0
# 8       140000.0  5.428528e+05  3070000.0
# 9       230000.0  7.735132e+05  2700000.0
# 10      316000.0  1.071771e+06  3600000.0
# 11      420000.0  1.496842e+06  7062500.0
# 12      835000.0  2.191222e+06  5350000.0
# 13     1780000.0  3.709615e+06  7700000.0

# %%
pd.crosstab(index = df['price'],
        columns = df['bedrooms'],
           value = df['price'],
           aggfunc = ['min', 'mean','max'])

# %% [markdown]
# ### 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.groupby(["waterfront",'view']).agg({'view': 'count'}).unstack('waterfront').fillna('-')
# Out:
#                view
# waterfront        0      1
# view
# 0           19489.0      -
# 1             331.0    1.0
# 2             955.0    8.0
# 3             491.0   19.0
# 4             184.0  135.0

# %%
3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
df.groupby(['floors','bedrooms']).agg({'floors': 'count'}).unstack('floors').fillna('-')
# .sort_values(['floors','bedrooms'])
# Out:
#           floors
# floors       1.0    1.5     2.0   2.5    3.0  3.5
# bedrooms
# 0            4.0      -     6.0     -    2.0  1.0
# 1          162.0   21.0    12.0   1.0    3.0    -
# 2         1951.0  182.0   497.0   5.0  123.0  2.0
# 3         5455.0  786.0  3118.0  56.0  405.0  4.0
# 4         2383.0  698.0  3682.0  58.0   61.0    -
# 5          605.0  185.0   775.0  23.0   13.0    -
# 6          104.0   30.0   119.0  14.0    5.0    -
# 7            9.0    7.0    19.0   2.0    1.0    -
# 8            5.0    1.0     6.0     -      -  1.0
# 9              -      -     4.0   2.0      -    -
# 10           1.0      -     2.0     -      -    -
# 11             -      -     1.0     -      -    -
# 33           1.0      -       -     -      -    -

# %% [markdown]
# ###### Больше всего одноэтажных домов с тремя спальнями

# %% [markdown]
# #### 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.head(3)
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
#
#    yr_renovated  sqft_living15  sqft_lot15  delta_renovated year_of_sale  \
# 0             0           1340        5650                0         2014
# 1          1991           1690        7639               40         2014
# 2             0           2720        8062                0         2015
#
#   month_of_sale
# 0            10
# 1            12
# ...

# %%
df.groupby(['condition','grade']).agg({'price': 'median'}).unstack('condition').fillna('-')
# Out:
#               price
# condition         1          2          3          4          5
# grade
# 1          142000.0          -          -          -          -
# 3                 -   280000.0    75000.0          -   262000.0
# 4          150000.0   145000.0   205000.0   238525.0          -
# 5          190000.0   180000.0   234475.0   229975.0   227450.0
# 6          255000.0   235000.0   265000.0   295000.0   285475.0
# 7          403500.0   305000.0   357500.0   390000.0   456000.0
# 8          932500.0   429000.0   485000.0   571250.0   696000.0
# 9                 -   715000.0   689000.0   823500.0  1078000.0
# 10                -  1752500.0   890000.0  1030000.0  1650000.0
# 11                -          -  1209500.0  1685000.0  2050000.0
# 12                -          -  1807500.0  2125000.0  1990000.0
# 13                -          -  2888000.0  5750000.0          -
